# %%
import pandas as pd

# %%
data = pd.read_csv("COVID-19_CBC_Data.csv")

# %%
data.head()
# Out:
#   Admission_DATE  Discharge_DATE or date of Death        Outcome  Patient Age  \
# 0       8/10/2020                        8/8/2020  Not Recovered           51
# 1       7/24/2020                        8/5/2020  Not Recovered           65
# 2       7/22/2020                        8/8/2020      Recovered           32
# 3       7/19/2020                        8/5/2020      Recovered           36
# 4       7/18/2020                        8/5/2020      Recovered           46
#
#    Gender Sample Collection Date  What kind of Treatment provided   \
# 0    Male               8/10/2020                 antibiotics,  O2
# 1  Female               7/24/2020    Paracetamol, Antibiotics,  O2
# 2    Male               7/22/2020                  Antibiotics, O2
# 3  Female               7/19/2020                  Antibiotics, O2
# 4    Male               7/18/2020    Paracetamol, Antibiotics,  O2
#
#   Ventilated (Y/N)  Red blood cell distribution width  Monocytes(%)  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Admission_DATE                     103 non-null    object
#  1   Discharge_DATE or date of Death    103 non-null    object
#  2   Outcome                            103 non-null    object
#  3   Patient Age                        103 non-null    int64
#  4   Gender                             103 non-null    object
#  5   Sample Collection Date             103 non-null    object
#  6   What kind of Treatment provided    103 non-null    object
#  7   Ventilated (Y/N)                   103 non-null    object
#  8   Red blood cell distribution width  103 non-null    float64
#  9   Monocytes(%)                       103 non-null    float64
#  10  White blood cell count             103 non-null    float64
# ...

# %%
data = data[['Outcome','Patient Age','Gender','What kind of Treatment provided ','Ventilated (Y/N)','Red blood cell distribution width'
             ,'Monocytes(%)','White blood cell count','Platelet Count','Platelet Count','Lymphocyte Count','Neutrophils Count']]

# %%
data = pd.get_dummies(data, drop_first=True)
data.head()
# Out:
#    Patient Age  Red blood cell distribution width  Monocytes(%)  \
# 0           51                               13.2           3.3
# 1           65                               40.0           3.0
# 2           32                               11.7           5.3
# 3           36                               13.0           5.0
# 4           46                               31.0           3.0
#
#    White blood cell count  Platelet Count  Platelet Count  Lymphocyte Count  \
# 0                   21.00          462.00          462.00              0.44
# 1                    8.79          180.66          180.66              4.39
# 2                    9.90          336.00          336.00              3.47
# 3                    9.95          240.10          240.10              0.80
# 4                   14.15          236.58          236.58              7.93
#
#    Neutrophils Count  Outcome_Recovered  Gender_Male  ...  \
# 0              19.43              False         True  ...
# ...

# %%
data.dtypes
# Out:
# Patient Age                                                         int64
# Red blood cell distribution width                                 float64
# Monocytes(%)                                                      float64
# White blood cell count                                            float64
# Platelet Count                                                    float64
# Platelet Count                                                    float64
# Lymphocyte Count                                                  float64
# Neutrophils Count                                                 float64
# Outcome_Recovered                                                    bool
# Gender_Male                                                          bool
# What kind of Treatment provided _Antibiotics                         bool
# What kind of Treatment provided _Antibiotics,  O2                    bool
# What kind of Treatment provided _Antibiotics,  O3                    bool
# ...

# %%
import numpy as np
y = np.array(data['Outcome_Recovered'])
X=np.array(data.drop('Outcome_Recovered',axis=1))

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
linear.score(X_test, y_test)
# Out:
# 0.7392693536006341

# %%
linear.score(X_train, y_train)
# Out:
# 0.9211440883077314

# %%
print('Coefficients: \n',linear.coef_)
print('Constant: \n', linear.intercept_)
# Out:
# Coefficients:
#  [-3.56796722e-03 -1.53430245e-03 -6.52194700e-03  7.01404905e-03
#   5.28545383e-04  5.28545383e-04 -1.00532589e-02 -6.65005717e-03
#  -4.53451695e-02  9.13652678e-02  8.96214167e-02 -2.13696484e-03
#  -2.13696484e-03  4.06786418e-02 -2.77555756e-17 -5.70493206e-03
#   1.48978591e-01  1.84658264e-01  1.33028566e-01  4.52603562e-02
#  -1.76156132e-01 -2.41117665e-01 -5.56861489e-01]
# Constant:
#  0.8945668736445731

# %%
data.head()
# Out:
#    Patient Age  Red blood cell distribution width  Monocytes(%)  \
# 0           51                               13.2           3.3
# 1           65                               40.0           3.0
# 2           32                               11.7           5.3
# 3           36                               13.0           5.0
# 4           46                               31.0           3.0
#
#    White blood cell count  Platelet Count  Platelet Count  Lymphocyte Count  \
# 0                   21.00          462.00          462.00              0.44
# 1                    8.79          180.66          180.66              4.39
# 2                    9.90          336.00          336.00              3.47
# 3                    9.95          240.10          240.10              0.80
# 4                   14.15          236.58          236.58              7.93
#
#    Neutrophils Count  Outcome_Recovered  Gender_Male  ...  \
# 0              19.43              False         True  ...
# ...

# %%
new_data = np.array([])
