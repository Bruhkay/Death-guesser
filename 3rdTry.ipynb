# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('COVID-19_CBC_Data.csv')

# %%
data = data[['Admission_DATE ','Outcome','Patient Age','Gender','What kind of Treatment provided ','Ventilated (Y/N)','Red blood cell distribution width'
             ,'Monocytes(%)','White blood cell count','Platelet Count','Platelet Count','Lymphocyte Count','Neutrophils Count']]

# %%
X = data.drop(['Outcome'], axis=1)
X.head()
# Out:
#   Admission_DATE   Patient Age  Gender What kind of Treatment provided   \
# 0       8/10/2020           51    Male                 antibiotics,  O2
# 1       7/24/2020           65  Female    Paracetamol, Antibiotics,  O2
# 2       7/22/2020           32    Male                  Antibiotics, O2
# 3       7/19/2020           36  Female                  Antibiotics, O2
# 4       7/18/2020           46    Male    Paracetamol, Antibiotics,  O2
#
#   Ventilated (Y/N)  Red blood cell distribution width  Monocytes(%)  \
# 0              Yes                               13.2           3.3
# 1              Yes                               40.0           3.0
# 2               No                               11.7           5.3
# 3               No                               13.0           5.0
# 4               No                               31.0           3.0
#
#    White blood cell count  Platelet Count  Platelet Count  Lymphocyte Count  \
# ...

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X.head()
# Out:
#    Patient Age  Red blood cell distribution width  Monocytes(%)  \
# 0           51                               13.2           3.3
# 1           65                               40.0           3.0
# 2           32                               11.7           5.3
# 3           36                               13.0           5.0
# 4           46                               31.0           3.0
#
#    White blood cell count  Platelet Count  Platelet Count  Lymphocyte Count  \
# 0                   21.00          462.00          462.00              0.44
# 1                    8.79          180.66          180.66              4.39
# 2                    9.90          336.00          336.00              3.47
# 3                    9.95          240.10          240.10              0.80
# 4                   14.15          236.58          236.58              7.93
#
#    Neutrophils Count  Admission_DATE _06/10/2020  Admission_DATE _06/11/2020  \
# ...

# %%
X = X.assign(const = 1)

# %%
y = data['Outcome']

# %%
y.head()
# Out:
# 0    Not Recovered
# 1    Not Recovered
# 2        Recovered
# 3        Recovered
# 4        Recovered
# Name: Outcome, dtype: object
